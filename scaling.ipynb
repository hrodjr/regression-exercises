# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from wrangle import wrangle_zillow #acquire and prepare module
from scipy import stats
from sklearn.preprocessing import MinMaxScaler, RobustScaler, StandardScaler, QuantileTransformer
from sklearn.model_selection import train_test_split

# %%
prepared_zillow_data = wrangle_zillow()

# %%
df = prepared_zillow_data
df.head()
# Out:
#     bedrooms  bathrooms  square_feet  tax_value  year county_codes
# 6          3          4         1620     847770  2011         6037
# 7          3          2         2077     646760  1926         6037
# 18         3          1         1244     169471  1950         6037
# 19         3          2         1300     233266  1950         6037
# 20         3          2         1222     290492  1951         6037

# %%
train_validate, test = train_test_split(df, test_size=.2, random_state=123)
train, validate = train_test_split(train_validate, test_size=.3, random_state=123)

# %%
#Train 
X_train = train[['bedrooms', 'bathrooms', 'square_feet', 'tax_value']]#features
y_train = train.year
X_validate = validate[['bedrooms', 'bathrooms', 'square_feet', 'tax_value']]#features
y_validate = validate.year
X_test = test[['bedrooms', 'bathrooms', 'square_feet', 'tax_value']]#features
y_test = test.year

# %% [markdown]
# ### Min-Max Scaling

# %%
scaler = MinMaxScaler()
# Note that we only call .fit with the training data,
# but we use .transform to apply the scaling to all the data splits.
scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_validate_scaled = scaler.transform(X_validate)
X_test_scaled = scaler.transform(X_test)

plt.figure(figsize=(13, 6))
plt.subplot(121)
plt.hist(X_train, bins=12, ec='black')
plt.title('Original')
plt.subplot(122)
plt.hist(X_train_scaled, bins=12, ec='black')
plt.title('Scaled')
# Out:
# Text(0.5, 1.0, 'Scaled')

# %% [markdown]
# ## inverse_transform MinMax

# %%
scaler = MinMaxScaler()
# Note that we only call .fit with the training data,
# but we use .transform to apply the scaling to all the data splits.
scaler.fit(X_train)

X_train_scaled = scaler.inverse_transform(X_train)
X_validate_scaled = scaler.inverse_transform(X_validate)
X_test_scaled = scaler.inverse_transform(X_test)

plt.figure(figsize=(13, 6))
plt.subplot(121)
plt.hist(X_train, bins=12, ec='black')
plt.title('Original')
plt.subplot(122)
plt.hist(X_train_scaled, bins=12, ec='black')
plt.title('Scaled')
# Out:
# Text(0.5, 1.0, 'Scaled')

# %% [markdown]
# # Standard Scaler

# %%
scaler = StandardScaler()
# Note that we only call .fit with the training data,
# but we use .transform to apply the scaling to all the data splits.
scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_validate_scaled = scaler.transform(X_validate)
X_test_scaled = scaler.transform(X_test)

plt.figure(figsize=(13, 6))
plt.subplot(121)
plt.hist(X_train, bins=12, ec='black')
plt.title('Original')
plt.subplot(122)
plt.hist(X_train_scaled, bins=12, ec='black')
plt.title('Scaled')
# Out:
# Text(0.5, 1.0, 'Scaled')

# %% [markdown]
# ## inverse_transform Standard

# %%
scaler = StandardScaler()
# Note that we only call .fit with the training data,
# but we use .transform to apply the scaling to all the data splits.
scaler.fit(X_train)

X_train_scaled = scaler.inverse_transform(X_train)
X_validate_scaled = scaler.inverse_transform(X_validate)
X_test_scaled = scaler.inverse_transform(X_test)

plt.figure(figsize=(13, 6))
plt.subplot(121)
plt.hist(X_train, bins=12, ec='black')
plt.title('Original')
plt.subplot(122)
plt.hist(X_train_scaled, bins=12, ec='black')
plt.title('Scaled')
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-10-35aa7281efef> in <module>
#       4 scaler.fit(X_train)
#       5
# ----> 6 X_train_scaled = scaler.inverse_transform(X_train)
#       7 X_validate_scaled = scaler.inverse_transform(X_validate)
#       8 X_test_scaled = scaler.inverse_transform(X_test)
#
# /usr/local/anaconda3/lib/python3.8/site-packages/sklearn/preprocessing/_data.py in inverse_transform(self, X, copy)
#     935                 X = X.copy()
#     936             if self.with_std:
# --> 937                 X *= self.scale_
#     938             if self.with_mean:
#     939                 X += self.mean_
#
# UFuncTypeError: Cannot cast ufunc 'multiply' output from dtype('float64') to dtype('int64') with casting rule 'same_kind'

# %% [markdown]
# # Robust Scaler

# %%
scaler = RobustScaler()
# Note that we only call .fit with the training data,
# but we use .transform to apply the scaling to all the data splits.
scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_validate_scaled = scaler.transform(X_validate)
X_test_scaled = scaler.transform(X_test)

plt.figure(figsize=(13, 6))
plt.subplot(121)
plt.hist(X_train, bins=12, ec='black')
plt.title('Original')
plt.subplot(122)
plt.hist(X_train_scaled, bins=12, ec='black')
plt.title('Scaled')
# Out:
# Text(0.5, 1.0, 'Scaled')

# %% [markdown]
# ## inverse_transform Robust

# %% [markdown]
# ##### Apply the .inverse_transform method to your scaled data. Is the resulting dataset the exact same as the original data?

# %%
scaler = RobustScaler()
# Note that we only call .fit with the training data,
# but we use .transform to apply the scaling to all the data splits.
scaler.fit(X_train)

X_train_scaled = scaler.inverse_transform(X_train)
X_validate_scaled = scaler.inverse_transform(X_validate)
X_test_scaled = scaler.inverse_transform(X_test)

plt.figure(figsize=(13, 6))
plt.subplot(121)
plt.hist(X_train, bins=12, ec='black')
plt.title('Original')
plt.subplot(122)
plt.hist(X_train_scaled, bins=12, ec='black')
plt.title('Scaled')
# Out:
# Text(0.5, 1.0, 'Scaled')

# %% [markdown]
# ##### Read the documentation for sklearn's QuantileTransformer. Use normal for the output_distribution and apply this scaler to your data. Visualize the result of your data scaling.

# %%
scaler = QuantileTransformer(output_distribution = 'normal')
scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_validate_scaled = scaler.transform(X_validate)
X_test_scaled = scaler.transform(X_test)

plt.figure(figsize=(13, 6))
plt.subplot(121)
plt.hist(X_train, bins=25, ec='black')
plt.title('Original')
plt.subplot(122)
plt.hist(X_train_scaled, bins=25, ec='black')
plt.title('Scaled')
# Out:
# Text(0.5, 1.0, 'Scaled')

# %% [markdown]
# ##### Use the QuantileTransformer, but omit the output_distribution argument. Visualize your results. What do you notice?

# %%
scaler = QuantileTransformer()
# Note that we only call .fit with the training data,
# but we use .transform to apply the scaling to all the data splits.
scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_validate_scaled = scaler.transform(X_validate)
X_test_scaled = scaler.transform(X_test)

plt.figure(figsize=(13, 6))
plt.subplot(121)
plt.hist(X_train, bins=25, ec='black')
plt.title('Original')
plt.subplot(122)
plt.hist(X_train_scaled, bins=25, ec='black')
plt.title('Scaled')
# Out:
# Text(0.5, 1.0, 'Scaled')

# %% [markdown]
# ##### Based on the work you've done, choose a scaling method for your dataset. Write a function within your prepare.py that accepts as input the train, validate, and test data splits, and returns the scaled versions of each. Be sure to only learn the parameters for scaling from your training data!
